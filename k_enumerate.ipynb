# %% [markdown]
# Often, when dealing with iterators, we also get need to keep a count of iterations. Python eases the programmers’ task by providing a built-in function enumerate() for this task. Enumerate() method adds a counter to an iterable and returns it in a form of enumerating object. This enumerated object can then be used directly for loops or converted into a list of tuples using the list() function.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python program to illustrate
# enumerate function
l1 = ["send mail", "cooking", "studying"]
s1 = "awesome"
  
# creating enumerate objects
obj1 = enumerate(l1)
obj2 = enumerate(s1)
  
print ("Return type:", type(obj1))
print (list(enumerate(l1)))

  
# changing start index to 0
print (list(enumerate(s1, 0)))

  
# changing start index to 2 from 0
print (list(enumerate(s1, 2)))

print (list(enumerate(s1, -2)))
# Out:
# Return type: <class 'enumerate'>
# [(0, 'send mail'), (1, 'cooking'), (2, 'studying')]
# [(0, 'a'), (1, 'w'), (2, 'e'), (3, 's'), (4, 'o'), (5, 'm'), (6, 'e')]
# [(2, 'a'), (3, 'w'), (4, 'e'), (5, 's'), (6, 'o'), (7, 'm'), (8, 'e')]
# [(-2, 'a'), (-1, 'w'), (0, 'e'), (1, 's'), (2, 'o'), (3, 'm'), (4, 'e')]

# %%
for count, ele in enumerate(l1):
    print(count)
    print(ele)
# Out:
# 0
# send mail
# 1
# cooking
# 2
# studying

# %%
for ele in enumerate(l1):

    print(ele)
# Out:
# (0, 'send mail')
# (1, 'cooking')
# (2, 'studying')

# %%
a = [44,55,66]
for something in enumerate(a): 
    print(something)
    print(type(something))
# Out:
# (0, 44)
# <class 'tuple'>
# (1, 55)
# <class 'tuple'>
# (2, 66)
# <class 'tuple'>

# %%
a = [44,55,66]
for counter, value in enumerate(a): 
    print(counter, value)
# Out:
# 0 44
# 1 55
# 2 66

# %%
a = [44,55,66]
for something in enumerate(a,101): 
    print(something)
# Out:
# (101, 44)
# (102, 55)
# (103, 66)

# %%
for ele in enumerate(l1):

    print(ele[0])
# Out:
# 0
# 1
# 2

# %%
A= ['Eng', 'Maths', 'Science']
B= [10, 20, 30]
l= list(zip(A,B))
print(l)
# Out:
# [('Eng', 10), ('Maths', 20), ('Science', 30)]

# %%
a = [1,2,3,4]

# %%
l1 = ["send mail", "cooking", "studying"]

# %%
var = enumerate(l1)

# %%
for something in var: 
    print(something)
# Out:
# (0, 'send mail')
# (1, 'cooking')
# (2, 'studying')

# %%
for s1, s2 in enumerate(l1): 
    print(s1, s2)
# Out:
# 0 send mail
# 1 cooking
# 2 studying

# %%
for s1, s2 in enumerate(l1): 
    print(s1)
# Out:
# 0
# 1
# 2

# %%
for s1,s2 in enumerate(l1): 
    print(s2)
# Out:
# send mail
# cooking
# studying
